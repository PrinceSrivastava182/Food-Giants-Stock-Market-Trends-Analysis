# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\Welcome\\Desktop\\FOOD GIANTS\\Datasets\\Food Giants.csv")

# %%
data
# Out:
#              Date    Open    High     Low   Close  Adj Close   Volume  \
# 0      17/03/1980  290.00  310.00  290.00  290.00     290.00    10000
# 1      18/03/1980  290.00  290.00  290.00  290.00     290.00        0
# 2      19/03/1980  290.00  310.00  290.00  290.00     290.00    20000
# 3      20/03/1980  290.00  290.00  290.00  290.00     290.00        0
# 4      21/03/1980  290.00  290.00  290.00  290.00     290.00        0
# ...           ...     ...     ...     ...     ...        ...      ...
# 69544  13/09/2024   16.96   17.69   16.94   17.57      17.57  4029900
# 69545  16/09/2024   17.59   17.98   17.57   17.73      17.73  2731200
# 69546  17/09/2024   17.83   17.95   17.71   17.77      17.77  2453000
# 69547  18/09/2024   17.79   17.88   17.59   17.63      17.63  2353200
# 69548  19/09/2024   17.90   18.05   17.74   17.87      17.87  3274900
#
#                   Company
# 0      Berkshire Hathaway
# 1      Berkshire Hathaway
# 2      Berkshire Hathaway
# ...

# %%
print("Dataset Information:")
data.info()
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69549 entries, 0 to 69548
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       69549 non-null  object
#  1   Open       69549 non-null  float64
#  2   High       69549 non-null  float64
#  3   Low        69549 non-null  float64
#  4   Close      69549 non-null  float64
#  5   Adj Close  69549 non-null  float64
#  6   Volume     69549 non-null  int64
#  7   Company    69549 non-null  object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 4.2+ MB
#
# Summary Statistics:
#                 Open           High            Low          Close  \
# count   69549.000000   69549.000000   69549.000000   69549.000000
# mean    19385.718167   19518.242445   19237.093912   19379.790709
# std     72884.659322   73394.593011   72298.390523   72842.539298
# min         0.000000       0.160000       0.150000       0.150000
# ...

# %%
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Company      0
# dtype: int64

# %%
duplicates = data.duplicated().sum()
print(f"\nDuplicate Rows: {duplicates}")
# Out:
# Duplicate Rows: 0

# %%
numeric_cols = data.select_dtypes(include=['number']).columns
for col in numeric_cols:
    plt.figure(figsize=(10, 5))
    sns.histplot(data[col], kde=True, bins=30, color='royalblue', edgecolor='black')
    plt.title(f'Distribution of {col}', fontsize=14, fontweight='bold')
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# Correlation heatmap (only numeric columns)
plt.figure(figsize=(12, 8))
numeric_data = data.select_dtypes(include=['number'])
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=14, fontweight='bold')
plt.show()

# %%
# Box plots for outlier detection
for col in numeric_cols:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=data[col], color='teal')
    plt.title(f'Box Plot of {col}', fontsize=14, fontweight='bold')
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.show()

# %%
# Pairplot to visualize relationships between numerical variables
sns.pairplot(data[numeric_cols], diag_kind='kde', corner=True)
plt.show()

# %%
# Violin plots to show distribution of numerical variables
for col in numeric_cols:
    plt.figure(figsize=(10, 5))
    sns.violinplot(x=data[col], palette='coolwarm')
    plt.title(f'Violin Plot of {col}', fontsize=14, fontweight='bold')
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.show()
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_6616\1801732117.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=data[col], palette='coolwarm')
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_6616\1801732117.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=data[col], palette='coolwarm')
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_6616\1801732117.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=data[col], palette='coolwarm')
# ...

# %%
# Scatter plot to visualize relationships between the two most correlated variables
if len(numeric_cols) >= 2:
    top_corr = numeric_data.corr().abs().unstack().sort_values(ascending=False)
    top_corr = top_corr[top_corr < 1].reset_index().iloc[0]
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=data[top_corr['level_0']], y=data[top_corr['level_1']], alpha=0.7, color='purple')
    plt.title(f'Scatter Plot of {top_corr["level_0"]} vs {top_corr["level_1"]}', fontsize=14, fontweight='bold')
    plt.xlabel(top_corr['level_0'], fontsize=12)
    plt.ylabel(top_corr['level_1'], fontsize=12)
    plt.grid(True)
    plt.show()

# %%
# Bar plot for mean values of numerical columns grouped by a categorical variable
if len(categorical_cols) > 0 and len(numeric_cols) > 0:
    plt.figure(figsize=(12, 6))
    sns.barplot(x=data[categorical_cols[0]], y=data[numeric_cols[0]], palette='coolwarm', ci=None)
    plt.xticks(rotation=45)
    plt.title(f'Bar Plot of {numeric_cols[0]} by {categorical_cols[0]}', fontsize=14, fontweight='bold')
    plt.xlabel(categorical_cols[0], fontsize=12)
    plt.ylabel(numeric_cols[0], fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
# Count plots for categorical variables
categorical_cols = data.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(12, 5))
    sns.countplot(y=data[col], order=data[col].value_counts().index, palette='viridis')
    plt.title(f'Count Plot of {col}', fontsize=14, fontweight='bold')
    plt.xlabel('Count', fontsize=12)
    plt.ylabel(col, fontsize=12)
    plt.show()
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_6616\4186318422.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=data[col], order=data[col].value_counts().index, palette='viridis')

# %% [markdown]
# # ----------------------------------EDA COMPLETED HERE--------------------------------
